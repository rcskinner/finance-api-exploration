# %% [markdown]
# # Notebook exploring the options available on the  IEX-Cloud financial API

# %%
import requests
token = os.environ.get("iex-token")

# %%
# Retrieve the stock price of an individual stock
target_stock = "qqq"
request_url = "https://cloud.iexapis.com/stable/stock/{stock_name}/quote?token={token}".format(stock_name= target_stock,token= token)
request_url
# Out:
# 'https://cloud.iexapis.com/stable/stock/qqq/quote?token=pk_5667f230e54b4285883bad9fc1311e26'

# %%
qqq =requests.get(request_url)
qqq.json()
# Out:
# {'symbol': 'QQQ',
#  'companyName': 'Invesco Capital Management LLC - Invesco QQQ Trust Series 1',
#  'primaryExchange': 'NASDAQ/NMS (GLOBAL MARKET)',
#  'calculationPrice': 'close',
#  'open': 313.78,
#  'openTime': 1615559400473,
#  'openSource': 'official',
#  'close': 315.46,
#  'closeTime': 1615582801179,
#  'closeSource': 'official',
#  'high': 318.23,
#  'highTime': 1615582799990,
#  'highSource': '15 minute delayed price',
#  'low': 311.391,
#  'lowTime': 1615565093031,
#  'lowSource': '15 minute delayed price',
#  'latestPrice': 315.46,
#  'latestSource': 'Close',
#  'latestTime': 'March 12, 2021',
#  'latestUpdate': 1615582801179,
#  'latestVolume': 69315601,
#  'iexRealtimePrice': None,
#  'iexRealtimeSize': None,
#  'iexLastUpdated': None,
#  'delayedPrice': 315.48,
#  'delayedPriceTime': 1615582799990,
#  'oddLotDelayedPrice': 315.48,
#  'oddLotDelayedPriceTime': 1615582799985,
#  'extendedPrice': 315.74,
#  'extendedChange': 0.28,
#  'extendedChangePercent': 0.00089,
# ...
